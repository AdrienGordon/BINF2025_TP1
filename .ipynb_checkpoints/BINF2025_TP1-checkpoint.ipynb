# %% [markdown]
# # Exercice 0 : échauffement

# %% [markdown]
# Dans ce TP nous allons représenter des distributions de données via différents types de graphes.
#
# Q1: Expliquez ce que représente et quand utiliser :
#
#
# *   un scatterplot
# *   un barplot
# *   un boxplot
# *   un violinplot
# *   un histogramme

# %% [markdown]
# ```markdown
# - Un scatterplot est un graphe contenant un nuage de points. Ces points peuvent être de taille variables si on leur rajoute un attribut conséquence.
# - Un barplot est un graphe avec des barres selon un axe qui représente une quantité/valeur pour sa valeur situé sur l'autre axe.
# - Un Boxplot est une figure avec une forme rectangulaire représentant où se situent les valeurs entre les premier et troisième quartile (on y indique aussi la médiane) et des barres sur les côtés opposés extrêmant montrant où se situent les maximum et minimum de l'ensemble des données
# - Un violinplot est similaire en principe à un boxplot car il montre la médiane, moyenne, quartiles et extremas des données. Par contre, le violinplot montre aussi la répartition des données d'où sa forme souvent de violon ou de larme.
# - Un histogramme est un graphe représentant l'occurence de chaque élément présent dans un ensemble de données.
# ```

# %% [markdown]
# # Exercice 1 : description de la base genbank

# %% [markdown]
# La base de données genbank est un des principaux dépots de données de génomes, elle gérée par le NCBI Américain (National Center for Biotechnology Information).
#
# Dans cet exercice, allons étudier le contenu général de cette base de données en utilisant les fichiers de résumés.

# %% [markdown]
# ---

# %% [markdown]
# Note technique : dans colab, vous pouvez monter votre google drive avec le code suivant :

# %% [markdown]
# ---

# %% [markdown]
# Q1. Téléchargez les fichier "overview.txt" et "README" disponibles ici :
#
#  https://ftp.ncbi.nlm.nih.gov/genomes/GENOME_REPORTS/

# %% [markdown]
# Q2. Quel est le format du fichier "overview.txt" ?

# %% [markdown]
# ```markdown
# Le fichier "overview.txt" est un .TSV soit Tab Separated Value.
# ```

# %% [markdown]
# Q3. Utilisez le fichier README pour comprendre ce que chaque colonne représente.

# %% [markdown]
# ```markdown
# 1. Organism/Name: Le nom de l'espèce (par ligne)
# 2. Kingdom: Le groupe taxonomique de l'espèce (Archae, Bactéries, Eukaryotes, Virus)
# 3. Group: Groupe général de l'organisme (sous classe du royaume) comme Animal (dans Eukaryotes)
# 4. Sub-Group: Sous-groupe (donc encore plus spécifique) comme Insecte (pour Animal)
# 5. Size: Taille en Mb (Mega base) du genome de l'organisme
# 6. Chrs: Nombre de chromosomes de l'organisme
# 7. Organelles: Nombre d'organelles (un des elements composant la cellule)
# 8. Plasmids: Nombre de plasmides (petite molécule d'ADN circulaire pouvant se répliquer indépendemment)
# 9. BioProjects: Nombre de projets de séquence de génome
# ```

# %% [markdown]
# ## Organisation de la base de données

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the overview.txt file into pandas
# Read as str, when numbers are needed try to convert to float while disregarding '-' (our NAN types)
filename = "./genome_reports/overview.txt"
df = pd.read_csv(filename, sep="\t", header=0, dtype=str)

df.columns.values
# Out:
# array(['#Organism/Name', 'Kingdom', 'Group', 'SubGroup', 'Size (Mb)',
#        'Chrs', 'Organelles', 'Plasmids', 'BioProjects'], dtype=object)

# %% [markdown]
# Q4. Combien d’organismes sont présents ?

# %%
len(df)
# Out:
# 87888

# %% [markdown]
# ### Royaumes

# %% [markdown]
# Q5. Qu'est-ce qu'un royaume ?

# %% [markdown]
# ```markdown
# Un règne (kingdom en anglais) est la deuxième classification du vivant en taxonomie. Il se situe sous les Domaines (ou Empire) et regroupe plusieurs embranchements dénommés phyla. Il y a actuellement 7 règnes différents:
# 1. Archaea
# 2. Bacteria
# 3. Protozoa
# 4. Chromista
# 5. Plantae
# 6. Fungi
# 7. Animalia
# ```

# %% [markdown]
# Q6. Combien de royaumes sont présents dans la base ?

# %% [markdown]
# ```markdown
# Dans la base seulement 4 sont présents.
# ```

# %% [markdown]
# Q7. Affichez le nombre d’organismes pour chaque royaume.

# %%
# TWO ORGANISMS HAVE THE SAME NAME IN THE BACTERIA KINGDOM SO NOT TOO SURE HOW TO PROCESS THIS
# no_dups_df = df.drop_duplicates(subset=["#Organism/Name"])
# len(no_dups_df)
# print(no_dups_df["Kingdom"].value_counts())

print(df["Kingdom"].value_counts())
# Out:
# Kingdom
# Bacteria     37492
# Viruses      32573
# Eukaryota    15560
# Archaea       2263
# Name: count, dtype: int64

# %% [markdown]
# ### Groupes

# %% [markdown]
# Q8. Qu’est-ce qu’un groupe ?

# %% [markdown]
# ```markdown
# Un groupe, aussi appelé phylum, est la catégorie se situant sous un règne, comme énoncé précedemment. Il y a deux définitions pour les groupes. Il y a une définition basé sur la parenté génétique, qui requiert que les espèces appartenant à un même groupe soit au minimum étroitement apparenté, mais cette définition est peu utilisée car avec le progrès technologique, l'analyse moléculaire des génomes peut montrer que des espèces pensées apparentées ne l'était pas, nécessitant donc un changement dans la classification. De ce fait, l'autre définition se base sur un plan d'organisation, regroupant des organismes par caractères partagés par l'ensemble du groupe.
# ```

# %%
# Q9. Combien de groupes sont présents par royaume ?

print(df[["Kingdom", "Group"]].drop_duplicates().groupby("Kingdom").count())
# Out:
#            Group
# Kingdom
# Archaea       11
# Bacteria      37
# Eukaryota      5
# Viruses        8

# %% [markdown]
# Q10. Affichez pour chaque royaume le nombre d’organismes par groupe.

# %%
df.groupby(["Kingdom", "Group"]).size()
# Out:
# Kingdom  Group
# Archaea  Asgard group                        61
#          Candidatus Hadarchaeota              8
#          Candidatus Hydrothermarchaeota       6
#          Candidatus Thermoplasmatota        432
#          DPANN group                        249
#                                            ...
# Viruses  dsRNA viruses                       30
#          unclassified archaeal viruses       15
#          unclassified phages               1233
#          unclassified virophages              3
#          unclassified viruses               684
# Length: 61, dtype: int64

# %% [markdown]
# ### Génomes

# %%
# CONVERT TO NUMERICAL DATA, DISREGARD NAN VALUES
num_df = df.copy()
cols_to_convert = ["Size (Mb)", "Chrs", "Organelles", "Plasmids", "BioProjects"]
num_df[cols_to_convert] = num_df[cols_to_convert].apply(pd.to_numeric, errors="coerce")

num_df
# Out:
#                                         #Organism/Name    Kingdom  \
# 0                         'Brassica napus' phytoplasma   Bacteria
# 1      'Catharanthus roseus' aster yellows phytoplasma   Bacteria
# 2               'Chrysanthemum coronarium' phytoplasma   Bacteria
# 3        'Conium maculatum' witches'-broom phytoplasma   Bacteria
# 4                       'Cynodon dactylon' phytoplasma   Bacteria
# ...                                                ...        ...
# 87883                           Zymoseptoria crescenta  Eukaryota
# 87884                          Zymoseptoria passerinii  Eukaryota
# 87885                       Zymoseptoria pseudotritici  Eukaryota
# 87886                             Zymoseptoria tritici  Eukaryota
# 87887               Zymoseptoria tritici fusarivirus 1    Viruses
#
#                      Group        SubGroup  Size (Mb)  Chrs  Organelles  \
# 0      Terrabacteria group  Mycoplasmatota   0.743598   NaN         NaN
# 1      Terrabacteria group  Mycoplasmatota   0.603949   1.0         NaN
# 2      Terrabacteria group  Mycoplasmatota   0.739592   NaN         NaN
# 3      Terrabacteria group  Mycoplasmatota   0.758186   NaN         NaN
# 4      Terrabacteria group  Mycoplasmatota   0.483935   NaN         NaN
# ...                    ...             ...        ...   ...         ...
# 87883                Fungi     Ascomycetes  47.032900   NaN         NaN
# 87884                Fungi     Ascomycetes  28.786300   NaN         NaN
# 87885                Fungi     Ascomycetes  32.097300   NaN         NaN
# 87886                Fungi     Ascomycetes  39.686300  21.0         1.0
# 87887                Other   Fusariviridae   0.005969   1.0         NaN
#
#        Plasmids  BioProjects
# 0           NaN          1.0
# 1           1.0          1.0
# 2           NaN          1.0
# 3           NaN          1.0
# 4           NaN          1.0
# ...         ...          ...
# 87883       NaN          1.0
# 87884       NaN          1.0
# 87885       NaN          6.0
# 87886       NaN         51.0
# 87887       NaN          1.0
#
# [87888 rows x 9 columns]

# %% [markdown]
# Q11. Affichez la distribution des tailles de génomes sur toute la base de données, utilisez un boxplot ou un violinplot (avec axe en log pour y voir quelque chose).

# %%
genplot = num_df.boxplot(column="Size (Mb)")
genplot.set_yscale("log")
genplot.set_ylabel("Genomic Size (Mb)")
# Out:
# Text(0, 0.5, 'Genomic Size (Mb)')

# %% [markdown]
# Q12. Affichez la distribution par royaume.

# %%
kngplot = num_df.boxplot(column="Size (Mb)", by="Kingdom")
kngplot.set_yscale("log")
kngplot.set_ylabel("Genomic Size (Mb)")

plt.show()

# %% [markdown]
# Q13. Affichez la distribution par groupe pour chaque royaume.

# %%
for kingdom_name, kingdom_df in num_df.groupby("Kingdom"):
    grpplot = kingdom_df.boxplot(column="Size (Mb)", by="Group")
    grpplot.set_yscale("log")

    # Axis Labels
    grpplot.set_ylabel("Genomic Size (Mb")
    grpplot.set_xlabel('')
    grpplot.set_xticklabels(grpplot.get_xticklabels(),rotation=90)

    # Set Figure Title (and remove the extra one added by pandas)
    grpplot.get_figure().suptitle(f"Genomic Distribution for {kingdom_name} Kingdom")
    grpplot.set_title("")

plt.show()
# kng_grp_plot = num_df.boxplot(column="Size (Mb)", by=["Kingdom", "Group"])
# kng_grp_plot.set_yscale("log")
# kng_grp_plot.set_ylabel("Genomic Size (Mb)")

# %% [markdown]
# Q14. Pour chaque royaume, donnez le nom et la taille de l’organisme avec le plus petit génome.

# %%
for kingdom_name, kingdom_df in num_df.groupby("Kingdom"):
    try:
        smallest_org = kingdom_df.loc[kingdom_df["Size (Mb)"].idxmin(skipna=True)]  
    except:
        print(f"Error: Receiving a NaN value for expected index of smallest organism's row for kingdom {kingdom_name}")
    
    print(f"Organism '{smallest_org["#Organism/Name"]}' has the smallest genome of kingdom '{kingdom_name}' with a size of {smallest_org["Size (Mb)"]} Mb")
# Out:
# Organism 'candidate division MSBL1 archaeon SCGC-AAA385M02' has the smallest genome of kingdom 'Archaea' with a size of 0.137797 Mb
# Organism 'bacterium AG-323-L21' has the smallest genome of kingdom 'Bacteria' with a size of 0.101587 Mb
# Organism 'Fragilariopsis kerguelensis' has the smallest genome of kingdom 'Eukaryota' with a size of 0.010223 Mb
# Organism 'Hippotragine gammaherpesvirus 1' has the smallest genome of kingdom 'Viruses' with a size of 0.000174 Mb

# %% [markdown]
# Q15. Même chose mais pour l'organisme avec le plus grand génome.

# %%
for kingdom_name, kingdom_df in num_df.groupby("Kingdom"):
    try:
        largest_org = kingdom_df.loc[kingdom_df["Size (Mb)"].idxmax(skipna=True)]  
    except:
        print(f"Error: Receiving a NaN value for expected index of largest organism's row for kingdom {kingdom_name}")
    
    print(f"Organism '{largest_org["#Organism/Name"]}' has the largest genome of kingdom '{kingdom_name}' with a size of {largest_org["Size (Mb)"]} Mb")
# Out:
# Organism 'archaeon' has the largest genome of kingdom 'Archaea' with a size of 13.3999 Mb
# Organism 'Thiomonas' has the largest genome of kingdom 'Bacteria' with a size of 25.1426 Mb
# Organism 'Viscum album' has the largest genome of kingdom 'Eukaryota' with a size of 91113.7 Mb
# Organism 'uncultured virus' has the largest genome of kingdom 'Viruses' with a size of 1150.68 Mb

# %% [markdown]
# ## Chromosomes

# %% [markdown]
# Q16. Affichez la distribution du nombre de chromosomes, sous la forme d’un histogramme, sur toute la base de données.

# %%
num_df.hist(column="Chrs", bins=range(50))
plt.show()

# %% [markdown]
# Q17. Même chose mais pour chaque royaume sous la forme d'un boxplot (ou violinplot).

# %%
kingdom_boxplt = num_df.boxplot(column="Chrs", by="Kingdom")
plt.show()

# %% [markdown]
# Q18. Qu’observez-vous ? Comment l’expliquez-vous ?

# %% [markdown]
# ```markdown
# Nous pouvons remarquer que les eukaryotes, cad des organismes a plusieurs cellules, au contraire des autres royaumes prokaryotes, cad uni-cellulaires, possedent une moyenne beaucoup plus elevee en terme de compte de chromosome. On pourrait peut-etre l'expliquer par le fait que des organismes eukaryotes possedent plus de fonctions a effectuer pour maintenir en vie une machinerie plus complexe et puis un risque augmente de variation aleatoire surement au niveau chromosmique au sein du meme organisme au cours de sa vie qui pourrait causer encore plus de diversite genetique?
# ```

# %% [markdown]
# Q19. Pour les Eucaryotes uniquement, affichez la distribution du nombre de chromosomes sous la forme d’un histogramme.

# %%
eukchr_hist = num_df[num_df["Kingdom"] == "Eukaryota"].hist(column="Chrs", bins=range(100))
eukchr_hist[0,0].set_title("Histogram of Chromosome Count among Eukaryotes")
plt.show()

# %% [markdown]
# Q20. Pour les Eucaryotes uniquement, affichez la taille des génomes en fonction du nombre de chromosomes, sous forme d'un graphe (scatter plot).

# %%
eukchrsz_scplt = num_df[num_df["Kingdom"] == "Eukaryota"].plot.scatter(x="Size (Mb)", y="Chrs")
eukchrsz_scplt.set_xscale("log")
plt.show()

# %% [markdown]
# Q21. Qu’observez-vous ?

# %% [markdown]
# ```markdown
# J'observe que la taille du genome d'un eukaryote semble etre reliee, meme faiblement, au nombre de chromosome ce qui voudrait dire logiquement que plus un eukaryote a de chromosomes, le plus il contient d'information, ou inversement le plus il y a d'information, plus grande est la chance qu'il est plus de chromosomes. Sinon, il y a un regroupement important vers la zone entre 10^2 Mb et 10^3.5 Mb pour 20-40 chromosomes.
# ```

# %% [markdown]
# ## Plasmides

# %% [markdown]
# Q22. Qu'est-ce qu'un plasmide ?

# %% [markdown]
# ```markdown
# Un plasmide est un brin a double helice d'ADN extra-chromosomique qui peut se repliquer par lui-meme (certes en utilisant ce que la cellule lui met a disposition) et est generalement trouve chez les bacteries, mais parfois aussi chez des eukaryotes ou des archees. Un plasmide est notamment beaucoup plus petit en taille qu'un chromosome et permet ainsi de stocker de l'information plus accessiblement et diversement, ce qui le rend plus utile pour une variete de taches spontanees comme se proteger contre des antibiotiques qui viennent neutraliser la bacterie par exemple. Aujourd'hui les plasmides nous sont tres utiles en laboratoire pour des choses comme l'ADN recombinant.
# ```

# %% [markdown]
# Q23. Affichez le nombre moyen de plasmides par royaume, sous forme d'un barplot.

# %%
num_df[["Kingdom", "Plasmids"]].fillna(0).groupby("Kingdom").mean().plot.bar()
plt.show()

# %% [markdown]
# Q24. Qu'observez-vous ?

# %% [markdown]
# ```markdown
# J'observe que ce sont surtout les bacteries et les archees qui possedent des plasmides, mais aussi chez quelques eukaryotes. Par contre inexistant chez les virus.
# ```

# %% [markdown]
# ## Projets

# %% [markdown]
# Q25. Qu'est-ce qu'un projet ?

# %% [markdown]
# ```markdown
# Un projet, ou 'bioproject' en anglais, est une grande base de donnees concernant le sequencage de genome, d'analyse epidiemologique, etc. qui est constamment mis a jour par de la recherche dans les domaines biologiques et biomoleculaire.
# ```

# %% [markdown]
# Q26. Affichez le nombre de projets moyen par organisme pour chaque royaume, sous forme d'un barplot.

# %%
mean_proj = num_df.groupby("Kingdom")["BioProjects"].mean()
mean_proj.plot.bar()
plt.show()

# %% [markdown]
# Q27. Combien d'organismes ont 0 projets ?

# %%
len(num_df[num_df["BioProjects"] == 0])
# Out:
# 0

# %% [markdown]
# Q28. Combien d'organismes ont > 1 projets ?

# %%
len(num_df[num_df["BioProjects"] > 1])
# Out:
# 18947

# %% [markdown]
# Q29. Affichez le nom et nombre du TOP 5 des organismes possédant le plus de projets.

# %%
num_df.nlargest(n=5, columns="BioProjects")[["#Organism/Name", "BioProjects"]]
# Out:
#                              #Organism/Name  BioProjects
# 29710                      Escherichia coli      39907.0
# 41700                 Klebsiella pneumoniae      21229.0
# 75957                 Staphylococcus aureus      17228.0
# 70775                   Salmonella enterica      16613.0
# 83689  uncultured Lachnospiraceae bacterium      15909.0

# %% [markdown]
# Q30. Expliquez rapidement pourquoi ces organismes sont les plus étudiés.

# %% [markdown]
# ```markdown
# Ce sont des bacteries extremement courantes qui nous impacte au jour le jour et qui en plus avoir de nombreuses mauvaises consequences donc il est normal qu'elles soient les plus etudiees, cela nous permet de mieux les prevenir.
# ```

# %% [markdown]
# # Exercice 3 : Gènes

# %% [markdown]
# Pour obtenir des informations plus précises sur les gènes contenus dans les différents organismes de genbank, nous allons travailler avec le fichier de résumé d'assemblage.

# %% [markdown]
# Q1. Récupérez le fichier "assembly_summary_genbank_historical.txt" situé ici:
# https://ftp.ncbi.nlm.nih.gov/genomes/ASSEMBLY_REPORTS/
#
# (On utilise le fichier historique car il est plus petit, l’autre fichier fait >1GB)

# %%
filename = "./genome_reports/assembly_summary_genbank_historical.txt"
df = pd.read_csv(filename, sep="\t", header=1, dtype=str)

num_df = df.copy()
cols_to_convert = ["taxid", "species_taxid", "replicon_count", "scaffold_count", "contig_count", "total_gene_count", "protein_coding_gene_count", "non_coding_gene_count"]
num_df[cols_to_convert] = num_df[cols_to_convert].apply(pd.to_numeric, errors="coerce")
print(df.columns.values)
# Out:
# ['#assembly_accession' 'bioproject' 'biosample' 'wgs_master'
#  'refseq_category' 'taxid' 'species_taxid' 'organism_name'
#  'infraspecific_name' 'isolate' 'version_status' 'assembly_level'
#  'release_type' 'genome_rep' 'seq_rel_date' 'asm_name' 'asm_submitter'
#  'gbrs_paired_asm' 'paired_asm_comp' 'ftp_path' 'excluded_from_refseq'
#  'relation_to_type_material' 'asm_not_live_date' 'assembly_type' 'group'
#  'genome_size' 'genome_size_ungapped' 'gc_percent' 'replicon_count'
#  'scaffold_count' 'contig_count' 'annotation_provider' 'annotation_name'
#  'annotation_date' 'total_gene_count' 'protein_coding_gene_count'
#  'non_coding_gene_count' 'pubmed_id']

# %% [markdown]
# Q2. Qu'est-ce que le GC content ? Pourquoi est-il mesuré?

# %% [markdown]
# ```markdown
# Le GC content correspond au nombre de bases nitrogenes (guanine ou cytosine) dans l'ADN. Il est mesure pour determine le cout de synthese d'une proteine (energie apporte pour augmenter la temperature et defaire certains liens).
# ```

# %% [markdown]
# Q3. Affichez la distribution du GC content dans tous les organismes de la liste, sous forme d'un violinplot.

# %%
# NOT SURE THIS IS WHAT WAS WANTED

import seaborn as sns

sns.violinplot(y=num_df["gc_percent"])
plt.show()

# %% [markdown]
# Q4. Qu'observez-vous ?

# %% [markdown]
# ```markdown
# La moyenne a un contenu GC assez elevee.
# ```

# %% [markdown]
# Q5. Affichez le GC content en fonction de la taille du génome, sous forme de scatter plot.

# %%
gcplot = num_df.plot.scatter(x="gc_percent", y="genome_size_ungapped")
gcplot.set_xscale("log")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 3
#       1 gcplot = num_df.plot.scatter(x="gc_percent", y="genome_size_ungapped")
#       2 gcplot.set_xscale("log")
# ----> 3 plt.show()
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/pyplot.py:614, in show(*args, **kwargs)
#     570 """
#     571 Display all open figures.
#     572
#    (...)
#     611 explicitly there.
#     612 """
#     613 _warn_if_gui_out_of_main_thread()
# --> 614 return _get_backend_mod().show(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/.local/lib/python3.12/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/.local/lib/python3.12/site-packages/IPython/core/formatters.py:238, in DisplayFormatter.format(self, obj, include, exclude)
#     236 md = None
#     237 try:
# --> 238     data = formatter(obj)
#     239 except:
#     240     # FIXME: log the exception
#     241     raise
#
# File ~/.local/lib/python3.12/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/.local/lib/python3.12/site-packages/IPython/core/formatters.py:282, in catch_format_error(method, self, *args, **kwargs)
#     280 """show traceback on failed format call"""
#     281 try:
# --> 282     r = method(self, *args, **kwargs)
#     283 except NotImplementedError:
#     284     # don't warn on NotImplementedErrors
#     285     return self._check_return(None, args[0])
#
# File ~/.local/lib/python3.12/site-packages/IPython/core/formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File ~/.local/lib/python3.12/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/backend_bases.py:2155, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2152     # we do this instead of `self.figure.draw_without_rendering`
#    2153     # so that we can inject the orientation
#    2154     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2155         self.figure.draw(renderer)
#    2156 if bbox_inches:
#    2157     if bbox_inches == "tight":
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/axes/_base.py:3181, in _AxesBase.draw(self, renderer)
#    3178 if artists_rasterized:
#    3179     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3181 mimage._draw_list_compositing_images(
#    3182     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3184 renderer.close_group('axes')
#    3185 self.stale = False
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/axis.py:1419, in Axis.draw(self, renderer)
#    1416 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1418 for tick in ticks_to_draw:
# -> 1419     tick.draw(renderer)
#    1421 # Shift label away from axes to avoid overlapping ticklabels.
#    1422 self._update_label_position(renderer)
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/axis.py:276, in Tick.draw(self, renderer)
#     273 renderer.open_group(self.__name__, gid=self.get_gid())
#     274 for artist in [self.gridline, self.tick1line, self.tick2line,
#     275                self.label1, self.label2]:
# --> 276     artist.draw(renderer)
#     277 renderer.close_group(self.__name__)
#     278 self.stale = False
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/lines.py:847, in Line2D.draw(self, renderer)
#     843         tpath, affine = (self._get_transformed_path()
#     844                          .get_transformed_points_and_affine())
#     845 else:
#     846     tpath, affine = (self._get_transformed_path()
# --> 847                      .get_transformed_points_and_affine())
#     849 if len(tpath.vertices):
#     850     # subsample the markers if markevery is not None
#     851     markevery = self.get_markevery()
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/transforms.py:2787, in TransformedPath.get_transformed_points_and_affine(self)
#    2779 def get_transformed_points_and_affine(self):
#    2780     """
#    2781     Return a copy of the child path, with the non-affine part of
#    2782     the transform already applied, along with the affine part of
#    (...)
#    2785     be performed.
#    2786     """
# -> 2787     self._revalidate()
#    2788     return self._transformed_points, self.get_affine()
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/transforms.py:2772, in TransformedPath._revalidate(self)
#    2766 def _revalidate(self):
#    2767     # only recompute if the invalidation includes the non_affine part of
#    2768     # the transform
#    2769     if (self._invalid == self._INVALID_FULL
#    2770             or self._transformed_path is None):
#    2771         self._transformed_path = \
# -> 2772             self._transform.transform_path_non_affine(self._path)
#    2773         self._transformed_points = \
#    2774             Path._fast_from_codes_and_verts(
#    2775                 self._transform.transform_non_affine(self._path.vertices),
#    2776                 None, self._path)
#    2777     self._invalid = 0
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/transforms.py:1620, in Transform.transform_path_non_affine(self, path)
#    1612 def transform_path_non_affine(self, path):
#    1613     """
#    1614     Apply the non-affine part of this transform to `.Path` *path*,
#    1615     returning a new `.Path`.
#    (...)
#    1618     ``transform_path_affine(transform_path_non_affine(values))``.
#    1619     """
# -> 1620     x = self.transform_non_affine(path.vertices)
#    1621     return Path._fast_from_codes_and_verts(x, path.codes, path)
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/transforms.py:2233, in BlendedGenericTransform.transform_non_affine(self, values)
#    2230     x_points = x_points.reshape((len(x_points), 1))
#    2232 if y.input_dims == 2:
# -> 2233     y_points = y.transform_non_affine(values)[:, 1:]
#    2234 else:
#    2235     y_points = y.transform_non_affine(values[:, 1])
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/transforms.py:2412, in CompositeGenericTransform.transform_non_affine(self, values)
#    2408 def transform_affine(self, values):
#    2409     # docstring inherited
#    2410     return self.get_affine().transform(values)
# -> 2412 def transform_non_affine(self, values):
#    2413     # docstring inherited
#    2414     if self._a.is_affine and self._b.is_affine:
#    2415         return values
#
# KeyboardInterrupt:

# %% [markdown]
# Q6. Qu'observez-vous ?

# %% [markdown]
# ```markdown
# Aucune idee jupyter lance pas la case proprement
# ```

# %% [markdown]
# Q7. Affichez la distribution du nombre de gènes, choisissez le plot.

# %%
genecount = num_df.boxplot(column="total_gene_count")
genecount.set_yscale("log")
plt.show()

# %% [markdown]
# Q8. Qu'observez-vous ?

# %% [markdown]
# ```markdown
# Beaucoup de valeurs aberrantes dans le dernier quartile.
# ```

# %% [markdown]
# Q9. Enlevez les données aberrantes (outliers)

# %%
prcs_gc = num_df[(num_df["total_gene_count"] < 1e5) & (num_df["total_gene_count"] > 0)]
prcs_gc.hist(column="total_gene_count", bins=100)
plt.show()

# %% [markdown]
# Q10. Comment avez-vous fait ? Quel seuil avez-vous choisi ?

# %% [markdown]
# ```markdown
# J'ai choisi visuellement le seuil ou l'on voit l'apparition des valeurs aberrantes dans le boxplot et j'ai enleve ceux pour lequel le nombre de genes etaient de 0
# ```

# %% [markdown]
# Q11. Y-a-t-il une corrélation entre taille du génome et nombre de gènes ?

# %%
plt.plot(prcs_gc["total_gene_count"], prcs_gc["genome_size"], "x")
plt.yscale("log")
plt.xlabel("Gene count")
plt.ylabel("Genomic Size (Mb)")
plt.show()

# %% [markdown]
# # Exercice 4: GC-content

# %% [markdown]
# Pour une séquence $s$, le contenu en GC est défini par :
#
# $GC(s)=\frac{\#G(s) + \#C(s)}{|s|}$,
#
# où $\#N(s)$ est le nombre de nucléotides $N$ dans la séquence $s$ et $|s|$ est la taille de $s$.

# %% [markdown]
# Q1. Récuperrez legénome de l’organisme *Acidianus ambivalens* à partir du FTP :
#
# https://ftp.ncbi.nlm.nih.gov/genomes/genbank/archaea/
#
# (dans latest_assembly_versions/GCA_009729015.1_ASM972901v1, le fichier avec l'extension "fna.gz")

# %% [markdown]
# Q2. Affichez le GC content global.

# %%
#Votre code ici

# %% [markdown]
# Q3. Pour détecter des variations locales de GC, on va utiliser une fenêtre glissante de taille N nucléotides (démarrer à la position N/2 et finir à |s| -N/2).
#
# Affichez le GC content le long du génome pour des fenêtres de tailles 50, 1000 ou 10000.

# %%
#Votre code ici

# %% [markdown]
# Q4. Qu’observez-vous ?

# %% [markdown]
# ```markdown
# Votre réponse ici
# ```

# %% [markdown]
# Q5. On va lisser le signal pour le rendre moins bruité en utilisant la fonction *savgol_filter* de *scipy.signal* avec les paramètres $51$ et $5$.

# %%
#Votre code ici

# %% [markdown]
# Q6. Finalement, on va rendre le code générique pour n'importe quel espèce. Modifier votre code pour qu'il prenne en entrée un nom de fichier de génome du ftp, et une taille de fenêtre, et affiche le GC content global et local.

# %%
#Votre code ici
